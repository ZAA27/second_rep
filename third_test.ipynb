# %%
# %config IPCompleter.greedy=True # чтобы tab работал быстрее
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import os
import sqlite3
# %pylab inline
from scipy.stats import bernoulli
from matplotlib import rcParams
import pylab 
import scipy.stats as stats
from tqdm.notebook import tqdm
from scipy.stats import ttest_ind

# figure size in inches
rcParams['figure.figsize'] = 12,6
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
test = np.random.normal(15,4,30000)

# %%
sns.histplot(test,color='g')
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# Функция распределения:

# %%
sns.ecdfplot(test)
plt.grid()

# %% [markdown]
# Плотность распределения:

# %%
sns.kdeplot(test,fill=True)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
second = np.random.normal(16.5,3.7,30000)

# %%
plt.figure(figsize = (16,10))
sns.histplot(test,color = 'g',alpha = 0.6)
sns.histplot(second, color = 'r', alpha = 0.6)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# # Лев:
#
# ![image.png](attachment:image.png)

# %%
print(777*1234)
# Out:
# 958818
